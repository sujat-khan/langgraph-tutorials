# %%
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
class SubState(TypedDict):

    input_text: str
    translated_text: str

# %%
from langchain_groq import ChatGroq

subgraph_llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.1
)

# %%
# subgraph_llm = ChatOpenAI(model='gpt-4o')

# %%
def translate_text(state: SubState):

    prompt = f"""
Translate the following text to Hindi.
Keep it natural and clear. Do not add extra content.

Text:
{state["input_text"]}
""".strip()
    
    translated_text = subgraph_llm.invoke(prompt).content

    return {'translated_text': translated_text}

# %%
subgraph_builder = StateGraph(SubState)

subgraph_builder.add_node('translate_text', translate_text)

subgraph_builder.add_edge(START, 'translate_text')
subgraph_builder.add_edge('translate_text', END)

subgraph = subgraph_builder.compile()

# %%
class ParentState(TypedDict):

    question: str
    answer_eng: str
    answer_hin: str

# %%
parent_llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.1)

# %%
def generate_answer(state: ParentState):

    answer = parent_llm.invoke(f"You are a helpful assistant. Answer clearly.\n\nQuestion: {state['question']}").content
    return {'answer_eng': answer}

# %%
def translate_answer(state: ParentState):

    # call the subgraph
    result = subgraph.invoke({'input_text': state['answer_eng']})

    return {'answer_hin': result['translated_text']}

# %%
parent_builder = StateGraph(ParentState)

parent_builder.add_node("answer", generate_answer)
parent_builder.add_node("translate", translate_answer)

parent_builder.add_edge(START, 'answer')
parent_builder.add_edge('answer', 'translate')
parent_builder.add_edge('translate', END)

# %%
graph = parent_builder.compile()

graph

# %%
graph.invoke({'question': 'What is quantum physics'})
# Out:
# {'question': 'What is quantum physics',
#  'answer_eng': '**Quantum physics** (also called quantum mechanics or quantum theory) is the branch of physics that describes how matter and energy behave at the smallest scales—typically at the level of atoms, electrons, photons, and other sub‑atomic particles.  \n\n---\n\n### Core Ideas\n\n| Concept | What it means | Why it matters |\n|---------|---------------|----------------|\n| **Quantization** | Certain physical quantities (energy, angular momentum, charge) can only take on discrete values, not a continuous range. | Explains why atoms emit/absorb light at specific wavelengths (spectral lines). |\n| **Wave‑particle duality** | Particles such as electrons and photons exhibit both wave‑like (interference, diffraction) and particle‑like (localized impacts) behavior. | Leads to phenomena like the double‑slit experiment. |\n| **Superposition** | A quantum system can exist in a combination of multiple possible states simultaneously until measured. | Underlies quantum computing (qubits can be 0 and 1 at once). |\n| **Entanglement** | Two or more particles can become linked so that the state of one instantly determines the state of the other, regardless of distance. | Enables quantum teleportation, secure communication (QKD). |\n| **Uncertainty principle** (Heisenberg) | Certain pairs of properties (e.g., position and momentum) cannot both be known with arbitrary precision at the same time. | Sets fundamental limits on measurement and explains stability of atoms. |\n| **Probability amplitudes** | The theory predicts probabilities of outcomes via complex-valued wavefunctions; the square of the amplitude gives the likelihood of a particular result. | Replaces deterministic trajectories of classical mechanics with statistical predictions. |\n\n---\n\n### Historical Milestones\n\n| Year | Event | Significance |\n|------|-------|--------------|\n| **1900** | Max Planck proposes quantized energy packets (quanta) to solve black‑body radiation. | Birth of quantum ideas. |\n| **1905** | Albert Einstein explains the photoelectric effect using light quanta (photons). | Shows light behaves as particles. |\n| **1913** | Niels Bohr model of the hydrogen atom with quantized electron orbits. | First successful atomic model using quantization. |\n| **1925‑1926** | Development of wave mechanics (Schrödinger) and matrix mechanics (Heisenberg). | Formal mathematical framework of quantum mechanics. |\n| **1927** | Heisenberg’s uncertainty principle; first experimental demonstration of electron diffraction. |\n| **1935** | Einstein‑Podolsky‑Rosen (EPR) paradox and Schrödinger’s “entanglement” term. | Highlights non‑local correlations. |\n| **1947‑1950s** | Quantum electrodynamics (QED) formulated (Feynman, Schwinger, Tomonaga). | Precise predictions for electromagnetic interactions. |\n| **1970s‑present** | Development of quantum field theory, Standard Model, quantum information science. | Extends quantum ideas to all fundamental forces and technologies. |\n\n---\n\n### How It Differs from Classical Physics\n\n| Classical view | Quantum view |\n|----------------|--------------|\n| Particles have definite positions and velocities at all times. | Only probabilities for positions/velocities; exact values emerge only upon measurement. |\n| Energy can vary continuously. | Energy levels are discrete in bound systems. |\n| Waves and particles are distinct phenomena. | Entities can be both; the distinction blurs. |\n| Deterministic evolution (Newton’s laws). | Evolution governed by the deterministic Schrödinger equation **until** a measurement collapses the wavefunction probabilistically. |\n\n---\n\n### Everyday and Technological Applications\n\n| Application | Quantum principle involved | Impact |\n|-------------|---------------------------|--------|\n| **Semiconductors & transistors** | Band structure from quantized electron states. | Foundation of modern electronics, computers, smartphones. |\n| **Lasers** | Stimulated emission of photons (quantized ener ...
#  'answer_hin': '**क्वांटम भौतिकी** (जिसे क्वांटम यांत्रिकी या क्वांटम सिद्धांत भी कहा जाता है) वह शाखा है जो पदार्थ और ऊर्जा के सबसे छोटे स्तरों—आमतौर पर परमाणु, इलेक्ट्रॉन, फोटॉन और अन्य उप‑परमाणु कणों—पर व्यवहार को वर्णित करती है।  \n\n---\n\n### मुख्य विचार\n\n| अवधारणा | अर्थ | महत्व |\n|---------|------|--------|\n| **परिमाणन (Quantization)** | कुछ भौतिक मात्राएँ (ऊर्जा, कोणीय संवेग, आवेश) केवल विविक्त (डिस्क्रीट) मान ले सकती हैं, निरंतर नहीं। | समझाता है कि परमाणु विशिष्ट तरंगदैर्घ्य (स्पेक्ट्रल लाइन्स) पर प्रकाश क्यों उत्सर्जित/अवशोषित करते हैं। |\n| **तरंग‑कण द्वैतता** | इलेक्ट्रॉन और फोटॉन जैसे कण तरंग‑समान (हस्तक्षेप, विवर्तन) और कण‑समान (स्थानीय टकराव) दोनों व्यवहार दिखाते हैं। | दो‑स्लिट प्रयोग जैसे घटनाओं को उत्पन्न करता है। |\n| **सुपरपोज़िशन** | एक क्वांटम प्रणाली कई संभावित अवस्थाओं के संयोजन में एक साथ मौजूद रह सकती है, जब तक कि माप न किया जाए। | क्वांटम कंप्यूटिंग का आधार (क्यूबिट एक साथ 0 और 1 हो सकते हैं)। |\n| **एंटैंगलमेंट** | दो या अधिक कण आपस में जुड़ सकते हैं जिससे एक का अवस्था तुरंत दूसरे की अवस्था निर्धारित कर देती है, दूरी चाहे जितनी भी हो। | क्वांटम टेलीपोर्टेशन, सुरक्षित संचार (QKD) को संभव बनाता है। |\n| **अनिश्चितता सिद्धांत** (हाइज़ेनबर्ग) | कुछ गुणों के जोड़े (जैसे स्थिति और संवेग) को एक साथ अनिश्चितता के साथ ही ज्ञात किया जा सकता है; दोनों को सटीक रूप से नहीं जाना जा सकता। | माप की मूलभूत सीमाएँ निर्धारित करता है और परमाणुओं की स्थिरता को समझाता है। |\n| **संभाव्यता आयाम** | सिद्धांत जटिल‑मान वाले वेवफ़ंक्शन के माध्यम से परिणामों की संभावनाएँ देता है; आयाम का वर्ग विशेष परिणाम की संभावना देता है। | क्लासिकल यांत्रिकी की नियतात्मक पथों को सांख्यिकीय भविष्यवाणियों से बदलता है। |\n\n---\n\n### ऐतिहासिक मील के पत्थर\n\n| वर्ष | घटना | महत्व |\n|------|-------|-------|\n| **1900** | मैक्स प्लैंक ने ब्लैक‑बॉडी विकिरण को समझाने के लिए ऊर्जा के क्वांटा (पैकेट) प्रस्तावित किए। | क्वांटम विचारों का जन्म। |\n| **1905** | अल्बर्ट आइंस्टीन ने फोटोइलेक्ट्रिक प्रभाव को प्रकाश क्वांटा (फोटॉन) के माध्यम से समझाया। | प्रकाश के कण‑समान व्यवहार को दिखाया। |\n| **1913** | नील्स बोहर ने हाइड्रोजन परमाणु के क्वांटाइज़्ड इलेक्ट्रॉन कक्षों वाला मॉडल प्रस्तुत किया। | क्वांटाइज़ेशन पर आधारित पहला सफल परमाणु मॉडल। |\n| **1925‑1926** | तरंग यांत्रिकी (श्रोडिंगर) और मैट्रिक्स यांत्रिकी (हाइज़ेनबर्ग) का विकास। | क्वांटम यांत्रिकी का औपचारिक गणितीय ढांचा। |\n| **1927** | हाइज़ेनबर्ग का अनिश्चितता सिद्धांत; इलेक्ट्रॉन विवर्तन का पहला प्रयोगात्मक प्रमाण। |\n| **1935** | आइंस्टीन‑पोडोल्स्की‑रॉज़ेन (EPR) विरोधाभास और श्रोडिंगर का “एंटैंगलमेंट” शब्द। | गैर‑स्थानीय सहसंबंधों को उजागर किया। |\n| **1947‑1950 के दशक** | क्वांटम इलेक्ट्रोडायनामिक्स (QED) का निर्माण (फ़ेयनमैन, श्विंगर, टॉमोनागा)। | विद्युत‑चुंबकीय अंतःक्रियाओं के लिए अत्यंत सटीक भविष्यवाणियाँ। |\n| **1970‑वर्तमान** | क्वांटम फ़ील्ड थ्योरी, स्टैंडर्ड मॉडल, क्वांटम सूचना विज्ञान का विकास। | क्वांटम सिद्धांत को सभी मूलभूत बलों और नई तकनीकों तक विस्तारित किया। |\n\n---\n\n### क्लासिकल भौतिकी से अंतर\n\n| क्लासिकल दृष्टिकोण | क्वांटम दृष्टिकोण |\n|---------------------|-------------------|\n| कणों की स्थिति और वेग हमेशा निश्चित होते हैं। | केवल संभावनाएँ होती हैं; माप के समय ही निश्चित मान प्राप्त होते हैं। |\n| ऊर्जा निरंतर रूप से बदल सकती है। | बंधित प्रणालियों में ऊर्जा स्तर विविक्त होते हैं। |\n| तरंग और कण अलग‑अलग घटनाएँ हैं। | इकाइयाँ दोनों हो सकती हैं; अंतर धुंधला हो जाता है। |\n| नियतात्मक विकास (न्यूटन के नियम)। | श्रोडिंगर समीकरण द्वारा नियतात्मक विकास **जब तक** माप नहीं किया जाता, तब वेवफ़ंक्शन संभाव्यात्मक रूप से गिरता है। |\n\n---\n\n### दैनिक और तकनीकी अनुप्रयोग\n\n| अनुप्रयोग | संबंधित क्वांटम सिद्धांत | प्रभाव |\n|-----------|------------------------|--------|\n| **सेमिकंडक्टर और ट्रांज़िस्टर** | क्वांटाइज़्ड इलेक्ट्रॉन अवस्थाओं से बैंड संरचना। | आधुनिक इलेक्ट्रॉनिक्स, कंप्यूटर, स्मार्टफ़ोन की नींव। |\n| **लेज़र** | फोटॉनों की उत्तेजित उत्सर्जन (क्वांटाइज़्ड ऊर्जा परिवर्तन)। | संचार, चिकित्सा, निर्माण आदि में उपयोग। |\n| **मैग्नेटिक रेज़ोनेंस इमेजिंग (MRI)** | नाभिकीय स्पिन का क्वांटाइज़ेशन और अनुनाद। | गैर‑आक्रामक चिकित्सा इमेजिंग। |\n| **परमाणु घड़ियाँ**  ...
