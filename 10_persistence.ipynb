# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver # Saves in RAM

# %%
load_dotenv()
from langchain_groq import ChatGroq
llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.1
)

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver()

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({'topic':'pizza'}, config=config1)
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to earn some *dough* and finally get a *slice* of the corporate pie! 🍕😄',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to earn some *dough* and finally get a *slice* of the corporate pie! 🍕😄', 'explanation': '**The joke**\n\n> *Why did the pizza apply for a job?*  \n> *Because it wanted to earn some **dough** and finally get a **slice** of the corporate pie!* 🍕😄  \n\n---\n\n## 1. The structure of the joke  \n\n1. **Setup** – “Why did the pizza apply for a job?”  \n   - This is a classic “Why did X do Y?” format that invites a punch‑line that explains an unexpected motivation.  \n2. **Punch‑line** – “Because it wanted to earn some *dough* and finally get a *slice* of the corporate pie!”  \n   - The humor comes from **puns** (play on words) that link pizza‑related terms with business‑world slang.\n\n---\n\n## 2. The wordplay (puns)  \n\n| Word in the punch‑line | Literal meaning (pizza world) | Figurative meaning (business world) | Why it’s funny |\n|------------------------|------------------------
# ...

# %%
list(workflow.get_state_history(config1))
# for Intermediate state values
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to earn some *dough* and finally get a *slice* of the corporate pie! 🍕😄', 'explanation': '**The joke**\n\n> *Why did the pizza apply for a job?*  \n> *Because it wanted to earn some **dough** and finally get a **slice** of the corporate pie!* 🍕😄  \n\n---\n\n## 1. The structure of the joke  \n\n1. **Setup** – “Why did the pizza apply for a job?”  \n   - This is a classic “Why did X do Y?” format that invites a punch‑line that explains an unexpected motivation.  \n2. **Punch‑line** – “Because it wanted to earn some *dough* and finally get a *slice* of the corporate pie!”  \n   - The humor comes from **puns** (play on words) that link pizza‑related terms with business‑world slang.\n\n---\n\n## 2. The wordplay (puns)  \n\n| Word in the punch‑line | Literal meaning (pizza world) | Figurative meaning (business world) | Why it’s funny |\n|------------------------|-----------------------
# ...

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pasta'}, config=config2)
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti get a promotion?\n\nBecause it *pasta*ble to *ketchup* with the competition and always *rolled* out the best ideas! 🍝😄',
# ...

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza apply for a job?\n\nBecause it wanted to earn some *dough* and finally get a *slice* of the corporate pie! 🍕😄', 'explanation': '**The joke**\n\n> *Why did the pizza apply for a job?*  \n> *Because it wanted to earn some **dough** and finally get a **slice** of the corporate pie!* 🍕😄  \n\n---\n\n## 1. The structure of the joke  \n\n1. **Setup** – “Why did the pizza apply for a job?”  \n   - This is a classic “Why did X do Y?” format that invites a punch‑line that explains an unexpected motivation.  \n2. **Punch‑line** – “Because it wanted to earn some *dough* and finally get a *slice* of the corporate pie!”  \n   - The humor comes from **puns** (play on words) that link pizza‑related terms with business‑world slang.\n\n---\n\n## 2. The wordplay (puns)  \n\n| Word in the punch‑line | Literal meaning (pizza world) | Figurative meaning (business world) | Why it’s funny |\n|------------------------|------------------------
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti get a promotion?\n\nBecause it *pasta*ble to *ketchup* with the competition and always *rolled* out the best ideas! 🍝😄', 'explanation': '**What makes the joke funny?**  \nThe humor comes from a series of puns that replace ordinary words with food‑related words that sound similar. Because the set‑up mentions “spaghetti,” the punch‑line leans into the same culinary theme, turning a typical workplace compliment into a goofy, food‑filled brag‑fest.\n\n| Phrase in the punch‑line | What it sounds like / what it replaces | Why it works |\n|--------------------------|----------------------------------------|--------------|\n| **“pasta‑ble”** | *possible* (or *capable*) | “Pasta” is the Italian staple that spaghetti belongs to. Swapping the “possi‑” for “pasta‑” creates a playful, unexpected twist that still sounds close enough to the original word for the brain to make the connection. |\n| **“ketchup with the competition
# ...

# %% [markdown]
# ### Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f1b1955-e7be-68a0-8000-d8638e4458e2"}})
# Out:
# StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_id': '1f1b1955-e7be-68a0-8000-d8638e4458e2'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-09-16T06:10:51.861741+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1b1955-e7b4-6350-bfff-5fe90b0e75aa'}}, tasks=(PregelTask(id='c5b35205-d485-888d-7eda-3aa9e864a2fb', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the spaghetti get a promotion?\n\nBecause it *pasta*ble to *ketchup* with the competition and always *rolled* out the best ideas! 🍝😄'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable": {"thread_id": "2", "checkpoint_id": "1f1b1955-e7be-68a0-8000-d8638e4458e2"}})
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the spaghetti get a promotion?\n\nBecause it knew how to *pasta* the competition and always *rolled* with the punches! 🍝😄',
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the spaghetti get a promotion?\n\nBecause it knew how to *pasta* the competition and always *rolled* with the punches! 🍝😄', 'explanation': '**Explanation of the joke**\n\n> *Why did the spaghetti get a promotion?*  \n> *Because it knew how to **pasta** the competition and always **rolled** with the punches! 🍝😄*\n\nThe humor comes from a combination of **puns** (playful word‑play) and a visual image that ties the punchline to the nature of spaghetti. Let’s break it down piece by piece.\n\n---\n\n### 1. “pasta” the competition  \n\n- **Literal meaning** – “Pasta” is the Italian staple food that includes spaghetti, penne, fusilli, etc.  \n- **Wordplay** – The phrase “pasta the competition” sounds exactly like the common idiom **“pass the competition.”**  \n- **Why it’s funny** – The joke pretends that spaghetti can *pass* (i.e., out‑perform) its rivals, but it does so by *using* the word “pasta,” which is literally what spaghetti
# ...

# %% [markdown]
# #### Updating State

# %%
workflow.update_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f1b1955-e7be-68a0-8000-d8638e4458e2", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f1b198a-9c91-6958-8001-236e5cf45e6c'}}

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'samosa'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1b198a-9c91-6958-8001-236e5cf45e6c'}}, metadata={'source': 'update', 'step': 1, 'parents': {}}, created_at='2026-09-16T06:34:26.686931+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1b1955-e7be-68a0-8000-d8638e4458e2'}}, tasks=(PregelTask(id='29d98f82-c0af-e37e-d0b1-82794f9ed06c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
workflow.invoke(None, {"configurable": {"thread_id": "2", "checkpoint_id": "1f1b198a-9c91-6958-8001-236e5cf45e6c"}})
# Out:
# {'topic': 'samosa',
#  'joke': 'Why did the samosa go to therapy?  \n\nBecause it was tired of being *filled* with secrets and wanted to finally *crumble* under pressure!',
# ...

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'samosa', 'joke': 'Why did the samosa go to therapy?  \n\nBecause it was tired of being *filled* with secrets and wanted to finally *crumble* under pressure!', 'explanation': '**The joke**\n\n> *Why did the samosa go to therapy?*  \n> *Because it was tired of being **filled** with secrets and wanted to finally **crumble** under pressure!*\n\n---\n\n## 1. What a samosa is  \n\nA samosa is a popular fried (or baked) snack in South Asian cuisine. It’s a triangular pastry that’s **filled** with a mixture of spiced potatoes, peas, meat, or other ingredients, then sealed and cooked until the dough becomes crisp and flaky.  \n\nBecause the food itself is defined by a *filling* and a *crisp, crumbly* exterior, the words “filled” and “crumble” instantly evoke the physical properties of a samosa.\n\n---\n\n## 2. The two layers of wordplay  \n\n| Phrase in the punchline | Literal meaning (food) | Figurative meaning (psychology) |\n|--------------------------|----
# ...

# %% [markdown]
# ### Fault Tolerance

# %%
from langgraph.graph import StateGraph, END
from langgraph.checkpoint.memory import InMemorySaver
from typing import TypedDict
import time

# %%
# 1. Define the state
class CrashState(TypedDict):
    input: str
    step1: str
    step2: str

# %%
# 2. Define steps
def step_1(state: CrashState) -> CrashState:
    print("✅ Step 1 executed")
    return {"step1": "done", "input": state["input"]}

def step_2(state: CrashState) -> CrashState:
    print("⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)")
    time.sleep(15)  # Simulate long-running hang
    return {"step2": "done"}

def step_3(state: CrashState) -> CrashState:
    print("✅ Step 3 executed")
    return {"done": True}

# %%
# 3. Build the graph
builder = StateGraph(CrashState)
builder.add_node("step_1", step_1)
builder.add_node("step_2", step_2)
builder.add_node("step_3", step_3)

builder.set_entry_point("step_1")
builder.add_edge("step_1", "step_2")
builder.add_edge("step_2", "step_3")
builder.add_edge("step_3", END)

checkpointer = InMemorySaver()
graph = builder.compile(checkpointer=checkpointer)

# %%
try:
    print("▶️ Running graph: Please manually interrupt during Step 2...")
    graph.invoke({"input": "start"}, config={"configurable": {"thread_id": 'thread-1'}})
except KeyboardInterrupt:
    print("❌ Kernel manually interrupted (crash simulated).")
# Out:
# ▶️ Running graph: Please manually interrupt during Step 2...
# ✅ Step 1 executed
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ❌ Kernel manually interrupted (crash simulated).

# %%
graph.get_state({"configurable": {"thread_id": 'thread-1'}})
# Out:
# StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1b1967-1973-6ad0-8001-387238c85f6f'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-09-16T06:18:33.414274+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1b1967-1968-689f-8000-1edfbeb24f64'}}, tasks=(PregelTask(id='192a5fd9-b6be-a1a8-024c-dc01177227d9', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done'}, next=('step_2',), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1b1967-1973-6ad0-8001-387238c85f6f'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-09-16T06:18:33.414274+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1b1967-1968-689f-8000-1edfbeb24f64'}}, tasks=(PregelTask(id='192a5fd9-b6be-a1a8-024c-dc01177227d9', name='step_2', path=('__pregel_pull', 'step_2'), error=None, interrupts=(), state=None, result=None),), interrupts=()),
# ...

# %%
# 6. Re-run to show fault-tolerant resume, None is the initial state
print("\n🔁 Re-running the graph to demonstrate fault tolerance...")
final_state = graph.invoke(None, config={"configurable": {"thread_id": 'thread-1'}})
print("\n✅ Final State:", final_state)
# Out:
# 🔁 Re-running the graph to demonstrate fault tolerance...
# ⏳ Step 2 hanging... now manually interrupt from the notebook toolbar (STOP button)
# ✅ Step 3 executed
#
# ✅ Final State: {'input': 'start', 'step1': 'done', 'step2': 'done'}

# %%
list(graph.get_state_history({"configurable": {"thread_id": 'thread-1'}}))
# Out:
# [StateSnapshot(values={'input': 'start', 'step1': 'done', 'step2': 'done'}, next=(), config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1b196c-2cd8-6fa9-8003-fa7589b77867'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-09-16T06:20:49.665798+00:00', parent_config={'configurable': {'thread_id': 'thread-1', 'checkpoint_ns': '', 'checkpoint_id': '1f1b196c-2cd2-6e31-8002-1cd963e2b8c3'}}, tasks=(), interrupts=()),
# ...
